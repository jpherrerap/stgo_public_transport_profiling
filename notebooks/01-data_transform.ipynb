# %%
# Quitamos la última línea del csv
# !head -n-1 viajes202208.csv > viajes202208_fix.csv

# %%
import pandas as pd
with open('viajes.csv',encoding='utf-16', errors = 'backslashreplace') as f:
    viajes_sample = pd.read_csv(f, sep=';', low_memory=False)
    viajes_dtypes = viajes_sample.dtypes

# %%
viajes_dtypes.to_dict()
# Out:
# {'nviaje': dtype('int64'),
#  'netapa': dtype('int64'),
#  'etapas': dtype('float64'),
#  'netapassinbajada': dtype('int64'),
#  'ultimaetapaconbajada': dtype('int64'),
#  'tviaje_seg': dtype('float64'),
#  'tviaje_min': dtype('float64'),
#  'dviajeeuclidiana_mts': dtype('float64'),
#  'dviajeenruta_mts': dtype('float64'),
#  'paraderosubida': dtype('O'),
#  'paraderobajada': dtype('O'),
#  'comunasubida': dtype('O'),
#  'comunabajada': dtype('O'),
#  'diseno777subida': dtype('float64'),
#  'diseno777bajada': dtype('float64'),
#  'tiemposubida': dtype('O'),
#  'tiempobajada': dtype('O'),
#  'periodosubida': dtype('O'),
#  'periodobajada': dtype('O'),
#  'tipodia': dtype('O'),
#  'mediahora': dtype('O'),
#  'contrato': dtype('float64'),
#  'factorexpansion': dtype('float64'),
#  'tiempomediodeviaje': dtype('O'),
#  'periodomediodeviaje': dtype('O'),
#  'tipodiamediodeviaje': dtype('O'),
#  't_1era_etapa': dtype('float64'),
#  'd_1era_etapa': dtype('float64'),
# ...

# %%
# Ahora podemos abrirlo con dask
import dask.dataframe as dd
viajes_sample = dd.read_csv("viajes202208_fix.csv", sep=';', encoding='utf-16')

# %%
with open('viajes.csv',encoding='utf-16', errors = 'backslashreplace') as f:
    viajes_sample = pd.read_csv(f, sep=';', low_memory=False, dtype=viajes_dtypes.to_dict())

# %%
viajes_sample = dd.read_csv("viajes202208_fix.csv", sep=';', encoding='utf-16', dtype=viajes_dtypes.to_dict())

# %%
# Tenemos 16.740.585 filas
# len(viajes_sample.index)

# %%
viajes_sample.head()
# Out:
#    nviaje  netapa  etapas  netapassinbajada  ultimaetapaconbajada  tviaje_seg
# 0       1       1     NaN                 1                     0         NaN  \
# 1       1       1     NaN                 1                     0         NaN
# 2       1       1     NaN                 1                     0         NaN
# 3       1       1     NaN                 1                     0         NaN
# 4       1       1     NaN                 1                     0         NaN
#
#    tviaje_min  dviajeeuclidiana_mts  dviajeenruta_mts
# 0         NaN                   NaN               NaN  \
# 1         NaN                   NaN               NaN
# 2         NaN                   NaN               NaN
# 3         NaN                   NaN               NaN
# 4         NaN                   NaN               NaN
#
#             paraderosubida  ... tipotransporte_4ta tespera_1era tespera_2da
# 0                EL PARRON  ...                NaN          NaN         NaN  \
# ...

# %%
x = viajes_sample.isna().all()

# %%
nviaje = viajes_sample['nviaje'].unique().compute()

# %%
print(nviaje)
# Out:
# 0      1
# 1      2
# 2      3
# 3      8
# 4      6
# 5      7
# 6      5
# 7      4
# 8      9
# 9     10
# 10    11
# 11    12
# 12    13
# 13    14
# 14    15
# 15    16
# 16    17
# 17    18
# 18    19
# 19    20
# 20    21
# 21    22
# 22    23
# 23    24
# 24    25
# 25    26
# 26    27
# 27    28
# 28    29
# 29    30
# 30    31
# 31    32
# 32    33
# 33    34
# Name: nviaje, dtype: int64

# %%
xc = x.compute()

# %%
xc[xc==True]
# Out:
# etapas                   True
# contrato                 True
# tespera_4ta_etapa        True
# ttrasbordo_4ta_etapa     True
# tcaminata_4ta_etapa      True
# dtransbordo_4ta_etapa    True
# linea_metro_bajada_1     True
# linea_metro_bajada_2     True
# linea_metro_bajada_3     True
# linea_metro_bajada_4     True
# tespera_1era             True
# tespera_2da              True
# tespera_3era             True
# tespera_4ta              True
# escolar                  True
# dviajeenbus              True
# dtype: bool
